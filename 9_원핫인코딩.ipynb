# %% [markdown]
# <a href="https://colab.research.google.com/github/HydrOpOtesJA99/A.I-learning/blob/main/9_%EC%9B%90%ED%95%AB%EC%9D%B8%EC%BD%94%EB%94%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9_원핫인코딩

# %% [markdown]
# ## 원핫인코딩이란

# %% [markdown]
# ![원핫인코딩.png](data:image/png;base64,...)

# %% [markdown]
# *   원핫인 코딩이란, 범주형 데이터(문자)를 실수형 데이터로 바꾸는 작업을 말한다
# *   위 Table을 '원핫인 코딩'을 통해 아래의 Table로 바꿔준다.
# *   범주형 데이터를 실수형으로 표현하기 위해 열을 추가한다고 생각하면 될듯?

# %% [markdown]
# ## 원핫인 코딩을 위한 pandas의 코드

# %%
# 학습할 데이터를 준비한다.

아이리스 = pd.read_csv('iris.csv')

# 원핫인코딩

아이리스 = pd.get_dummies(아이리스)

# %% [markdown]
# ![원핫인코딩_1.png](data:image/png;base64,...)

# %% [markdown]
# *   퍼셉트론으로 표현한다면 위와 같이 표현될 것이다.
